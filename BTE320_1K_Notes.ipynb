# %% [markdown]
# <a href="https://colab.research.google.com/github/mishacohen/BTE320/blob/main/BTE320_1K_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello')
# Out:
# Hello

# %%
x = 2
